# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
plt.matshow(X_train[3])

# %%
y_train[3]
# Out:
# 1

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# scale the data to increase the acuricy in this case we should device our whole data set by 255

# %%
X_train = X_train/255
X_test = X_test/255

# %% [markdown]
# now it is time to change the 3 dimensions arry to 2 d_array by calling reshape function

# %%
X_train_flattened = X_train.reshape(len(X_train), 28*28)
X_test_flattened = X_test.reshape(len(X_test), 28*28)

# %%
X_train_flattened.shape
# Out:
# (60000, 784)

# %%
model.evaluate(X_test_flattened, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9148 - loss: 0.3066
# [0.2699926793575287, 0.925599992275238]

# %%
X_test_predicted = model.predict(X_test_flattened)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
plt.matshow(X_test[0])

# %%
np.argmax(X_test_predicted[0])
# Out:
# 7

# %%
y_predicted_label = [np.argmax(i) for i in X_test_predicted]
y_predicted_label[:5]
# Out:
# [7, 2, 1, 0, 4]

# %% [markdown]
# now by using confusion matrix we can check where our model got errors or got confusion

# %%
cm = tf.math.confusion_matrix(labels=y_test, predictions=y_predicted_label)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 959,    0,    1,    2,    0,    5,   10,    2,    1,    0],
#        [   0, 1118,    3,    2,    0,    1,    4,    2,    5,    0],
#        [   4,   11,  923,   20,   11,    5,   14,    9,   33,    2],
#        [   1,    0,   16,  939,    1,   15,    2,   10,   20,    6],
#        [   1,    2,    2,    1,  933,    0,   12,    3,    8,   20],
#        [   8,    3,    2,   45,   12,  771,   17,    4,   26,    4],
#        [   8,    3,    5,    1,    7,   11,  920,    2,    1,    0],
#        [   1,    8,   26,    7,   10,    0,    0,  950,    1,   25],
#        [   6,   11,    6,   31,    9,   30,   10,    9,  856,    6],
#        [  10,    7,    1,   14,   48,    8,    0,   28,    6,  887]])>

# %%
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True, fmt = 'd')
plt.xlabel = 'predectied'
plt.ylabel = 'Truth'

# %% [markdown]
# now let's add a hidden layer to improve the performance

# %%
model_h = keras.Sequential([
    keras.layers.Dense(100, input_shape=(784,), activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

model_h.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_h.fit(X_train_flattened, y_train, epochs = 5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8710 - loss: 0.4521
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9630 - loss: 0.1289
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9743 - loss: 0.0877
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9805 - loss: 0.0669
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9856 - loss: 0.0487

# %%
model_h.evaluate(X_test_flattened, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9728 - loss: 0.0850
# [0.07440964132547379, 0.9763000011444092]

# %%
Y_h_predicted = model_h.predict(X_test_flattened)
y_predicted_label = [np.argmax(i) for i in Y_h_predicted]
cm_h = tf.math.confusion_matrix(labels=y_test, predictions=y_predicted_label)
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True, fmt = 'd')
plt.xlabel = 'predectied'
plt.ylabel = 'Truth'
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# we have another way to avoide flattened sparately rather than that we can add a new heddin layer with keras.flatten
# like this :
# keras.layers.flatten(input_shape(28,28)),
